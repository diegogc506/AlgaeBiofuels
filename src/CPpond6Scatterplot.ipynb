# %% [markdown]
# Import the necessary libaries.

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

import numpy as np
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# /kaggle/input/the-algae-testbed-publicprivate-partnership-atp3/ATP3-UFS-Instrumentation-daily.csv
# /kaggle/input/the-algae-testbed-publicprivate-partnership-atp3/ATP3-UFS-HarvestData.csv
# /kaggle/input/the-algae-testbed-publicprivate-partnership-atp3/ATP3-UFS-Weather.csv
# /kaggle/input/the-algae-testbed-publicprivate-partnership-atp3/ATP3-UFS-PondOperationalData.csv
# /kaggle/input/the-algae-testbed-publicprivate-partnership-atp3/ATP3-UFS-SummaryCombinedData.csv
# /kaggle/input/the-algae-testbed-publicprivate-partnership-atp3/ATP3-UFS-Instrumentation.csv
# /kaggle/input/the-algae-testbed-publicprivate-partnership-atp3/ATP3-UFS-Weather-daily.csv
# /kaggle/input/the-algae-testbed-publicprivate-partnership-atp3/ATP3-UFS-Composition.csv
# Setup Complete

# %% [markdown]
# Visualize the head of the composition data file.

# %%
composition_data = pd.read_csv("../input/the-algae-testbed-publicprivate-partnership-atp3/ATP3-UFS-Composition.csv", index_col=0)
composition_data.head()
# Out:
#             Analytical.Sample.ID          DATETIME  Protein.AF  \
# Tracking.ID
# 1                ASU_P1_131017_1  10/17/2013 14:29       26.36
# 2                ASU_P1_102413_1   10/24/2013 8:00       43.86
# 3                ASU_P1_103013_1   10/30/2013 8:15       44.32
# 4                ASU_P1_110413_1    11/4/2013 8:00       43.07
# 5                ASU_P2_102413_1   10/24/2013 8:00       43.35
#
#              FAME.Lipids.AF  Carbohydrates.AF ExperimentID SiteID StrainID  \
# Tracking.ID
# 1                     23.76             16.35    OCT172013    ASU     KA32
# 2                     10.77              6.26    OCT172013    ASU     KA32
# 3                       NaN              8.45    OCT172013    ASU     KA32
# 4                     13.09              8.18    OCT172013    ASU     KA32
# 5                     11.17              6.44    OCT172013    ASU     KA32
#
#                       SourceID            BatchID  Duration.days PondID
# Tracking.ID
# 1            KA32_10042013_CRE  KA32_10172013_SPW           0.00   inoc
# 2            KA32_10042013_CRE  KA32_10172013_SPW           6.73     P1
# 3            KA32_10042013_CRE  KA32_10172013_SPW          12.74     P1
# 4            KA32_10042013_CRE  KA32_10172013_SPW          17.73     P1
# 5            KA32_10042013_CRE  KA32_10172013_SPW           6.73     P2

# %%
comp_data_oct172013 = composition_data.loc[composition_data.SiteID == 'CP'].loc[composition_data.PondID == 'P6']
comp_data_oct172013.head()
# Out:
#             Analytical.Sample.ID         DATETIME  Protein.AF  FAME.Lipids.AF  \
# Tracking.ID
# 80                    P5_31Oct13  10/31/2013 8:15       48.96           16.42
# 86                   P5_8Nov2013   11/8/2013 9:40       40.65           15.46
# 92                  P5_22Nov2013  11/22/2013 8:55       43.22           15.94
# 98                  P5_25Nov2013  11/25/2013 9:45       37.57           21.93
# 103                 P5_29Nov2013  11/29/2013 8:25       33.42           26.44
#
#              Carbohydrates.AF ExperimentID SiteID StrainID  \
# Tracking.ID
# 80                       8.32    OCT172013     CP     KA32
# 86                       7.64    OCT172013     CP     KA32
# 92                       9.74    OCT172013     CP     KA32
# 98                       9.46    OCT172013     CP     KA32
# 103                     11.28    OCT172013     CP     KA32
#
#                          SourceID        BatchID  Duration.days PondID
# Tracking.ID
# 80           KA32_4Oct2013_Panels  KA32_4Oct2013          13.61     P5
# 86           KA32_4Oct2013_Panels  KA32_4Oct2013          21.67     P5
# 92            KA32_9Oct2013_Pond3  KA32_9Oct2013          35.64     P5
# 98            KA32_9Oct2013_Pond3  KA32_9Oct2013          38.68     P5
# 103           KA32_9Oct2013_Pond3  KA32_9Oct2013          42.62     P5

# %%
sns.scatterplot(comp_data_oct172013['Duration.days'], comp_data_oct172013['FAME.Lipids.AF'])

# %%
comp_data_oct172013.columns
# Out:
# Index(['Analytical.Sample.ID', 'DATETIME', 'Protein.AF', 'FAME.Lipids.AF',
#        'Carbohydrates.AF', 'ExperimentID', 'SiteID', 'StrainID', 'SourceID',
#        'BatchID', 'Duration.days', 'PondID'],
#       dtype='object')
